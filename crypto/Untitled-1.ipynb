# %%
from math import log2

# %%
ialpha = -log2(1/8)
isigma = -log2(7/16)
ilambda = -log2(1/4)
ibeta = -log2(3/16)

h = ialpha*1/8 + isigma*7/16 + ilambda*1/4 + ibeta*3/16
print(h)
l = 2 * 1/8 + 2 * 1/4 + 2* 3/16 + 2 * 7/16
print(l)

h/l
print(1/8,3/16, 1/4, 7/16)
0.4375+0.5625
# Out:
# 1.8496017527145812
# 2.0
# 0.125 0.1875 0.25 0.4375
# 1.0
